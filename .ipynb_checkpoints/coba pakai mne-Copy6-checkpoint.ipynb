# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from BCI2kReader import BCI2kReader as b2k
from matplotlib import pyplot
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image as im
import os
from sklearn.preprocessing import normalize #machine learning algorithm library

# %%
def signaltonoise(a, axis=0, ddof=0):
    a = np.asanyarray(a)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.where(sd == 0, 0, m/sd)

# %%
def data_extraction_all(raw, labels):
    combine_dataframe = []
    for i in range(16):
        mean = raw.values[i].mean() #mean setiap channel (channel = index array)
        combine_dataframe.append(float(mean))

        std = raw.values[i].std()
        combine_dataframe.append(float(std))

        snr = signaltonoise(raw.values[i])
        combine_dataframe.append(float(snr))
        
    combine_dataframe.append(labels)
    final_dataframe = pd.DataFrame(combine_dataframe, index = ['FP1_mean', 'FP1_std', 'FP1_snr', 'F3_mean', 'F3_std', 'F3_snr', 'F7_mean', 'F7_std', 'F7_snr', 'T3_mean', 'T3_std', 'T3_snr','T5_mean', 'T5_std', 'T5_snr','O1_mean', 'O1_std', 'O1_snr','C4_mean', 'C4_std', 'C4_snr','FP2_mean', 'FP2_std', 'FP2_snr','Fz_mean', 'Fz_std', 'Fz_snr','F4_mean', 'F4_std', 'F4_snr','F8_mean', 'F8_std', 'F8_snr','C3_mean', 'C3_std', 'C3_snr','Cz_mean', 'Cz_std', 'Cz_snr','Pz_mean', 'Pz_std', 'Pz_snr','Oz_mean', 'Oz_std', 'Oz_snr','O2_mean', 'O2_std', 'O2_snr', 'label'])
    final_dataframe = pd.DataFrame(combine_dataframe)
    final_dataframe = pd.DataFrame.transpose(final_dataframe)
    final_dataframe.reset_index()
    return final_dataframe

# %%
import glob
import os
df_normal = pd.DataFrame([], )
label = 'NORMAL'
for filename in glob.glob('./dataset - Copy/normal/*.dat'):
    with b2k.BCI2kReader(filename) as test:
        my_states = test.read(-1)
        my_signals, stateslice = test[100:5000]
        raw = pd.DataFrame(my_signals)
        #raw_fix = pd.concat([raw, raw])
        #raw_fix = pd.DataFrame.transpose(raw)
        
        df_normal = df_normal.append(data_extraction_all(raw, label))
        
        #df.append(data_extraction_all(raw))
df_normal.reset_index(drop=True, inplace=True)

# %%
df_normal.head(10)
# Out:
#          0          1         2         3          4         5         6   \
# 0 -0.624347  23.979383 -0.026037  0.116477  19.913599  0.005849  0.125252
# 1 -0.676386  19.131838 -0.035354  0.368772  17.258625  0.021367 -0.297263
# 2 -0.233317  29.305481 -0.007962 -1.072103  29.843842 -0.035924  2.780742
# 3 -1.274891  29.377941 -0.043396   -0.2455   28.67967  -0.00856 -3.985551
# 4  2.870057  31.392519  0.091425   2.72708  23.715925  0.114989  3.562276
#
#           7         8         9   ...        39         40        41  \
# 0  20.784523  0.006026   0.57154  ...   0.31645  21.953053  0.014415
# 1  22.396791 -0.013273 -0.454821  ... -1.362617  17.229414 -0.079087
# 2  31.387653  0.088593  0.057959  ... -0.669388  27.014055 -0.024779
# 3  28.727942 -0.138734 -1.126613  ...  1.071085  29.261433  0.036604
# 4  30.684959  0.116092  3.040855  ...  2.097911   20.13583  0.104188
#
#          42         43        44        45         46        47      48
# 0   1.01972  21.025196    0.0485  0.225384  22.052794   0.01022  NORMAL
# 1  -2.05988  19.018234 -0.108311 -1.570773   17.78528 -0.088319  NORMAL
# 2  0.482056  27.717913  0.017391  1.925537  28.183655  0.068321  NORMAL
# 3  1.460634  26.562658  0.054988  1.432005   26.86068  0.053312  NORMAL
# 4  1.905117  20.715286  0.091967  1.652162  21.331612  0.077451  NORMAL
#
# [5 rows x 49 columns]

# %%
df_epileps = pd.DataFrame([])
label2 = 'AUTISM'
for filename in glob.glob('./dataset - Copy/autism/*.dat'):
    with b2k.BCI2kReader(filename) as test2:
        my_states2 = test2.read(-1)
        my_signals2, stateslice2 = test2[100:5000]
        raw2 = pd.DataFrame(my_signals2)
        df_epileps = df_epileps.append(data_extraction_all(raw2, label2))
df_epileps.reset_index(drop=True, inplace=True)

# %%
df_epileps.head(20)
# Out:
#            0           1         2          3           4         5   \
# 0   -3.104909   34.016403 -0.091277  -8.819782    56.12722 -0.157139
# 1   44.203735  455.095703  0.097131  91.362656  549.767212  0.166184
# 2   -8.550959   91.352348 -0.093604 -14.699034  106.559555 -0.137942
# 3   -1.037109   33.312073 -0.031133  -7.550764   57.545147 -0.131215
# 4    0.591081   310.90451  0.001901   6.541457   91.078812  0.071822
# 5    3.251368  319.129211  0.010188 -12.142856  232.488174  -0.05223
# 6   -0.560912    76.02356 -0.007378  -1.246537   61.854919 -0.020153
# 7   -0.768482   34.711796 -0.022139  -2.048633    27.96987 -0.073244
# 8   -1.871585   43.747368 -0.042782  -1.327664   22.958767 -0.057828
# 9    1.907379   41.650661  0.045795   1.626422   24.721689  0.065789
# 10  -6.008857  102.754066 -0.058478  -8.091721  143.963516 -0.056207
#
#           6           7         8         9   ...        39          40  \
# 0   -0.87487   28.970325 -0.030199  0.852632  ...  -0.77981     26.1565
# 1   1.134602  343.217102  0.003306   2.88162  ... -3.187153  323.585388
# 2  -6.002451   79.843231 -0.075178 -4.278653  ... -8.492919   92.490746
# 3  -1.069819   28.474209 -0.037572  0.186861  ...  2.043145   34.347099
# 4   7.374287  129.444763  0.056969  8.847253  ...  4.435018   52.149452
# 5  -4.516046  223.062286 -0.020246 -9.342538  ... -15.26706  216.459137
# 6  -1.687734   48.008522 -0.035155 -1.205456  ... -0.800648   45.191753
# 7   1.923287   24.240623  0.079341 -1.003429  ...  0.059959   26.261909
# 8  -0.627061   19.183924 -0.032687 -0.475463  ...  -1.11148   21.750071
# 9   0.210452     28.3811  0.007415   0.63591  ...  2.161743   24.025276
# 10 -4.327903  105.304161 -0.041099 -7.982169  ... -6.694507  101.011597
#
#           41         42          43        44         45          46  \
# 0  -0.029813   2.254434   92.212738  0.024448   3.604031   50.467869
# 1  -0.009849  -3.991848  293.772247 -0.013588  -3.446635  364.523651
# 2  -0.091825  -6.049943   90.092659 -0.067152  -6.082263   87.958145
# 3   0.059485  -0.184046   27.136555 -0.006782  -1.030657     26.9391
# 4   0.085044   3.727485    52.24884  0.071341    3.94482   50.294724
# 5  -0.070531  -7.659545  253.644135 -0.030198 -16.338644  231.793091
# 6  -0.017717  -0.758953   47.726425 -0.015902  -0.769015   52.411179
# 7   0.002283  -0.826784   53.443165  -0.01547  -0.455056   44.132179
# 8  -0.051102  13.829736  163.514069  0.084578  -1.258452  102.229568
# 9   0.089978   1.694341    25.34133  0.066861    1.85493   25.669868
# 10 -0.066275  -7.693645  123.466301 -0.062314  -6.523611  138.578613
#
#           47      48
# 0   0.071412  AUTISM
# 1  -0.009455  AUTISM
# 2   -0.06915  AUTISM
# 3  -0.038259  AUTISM
# 4   0.078434  AUTISM
# 5  -0.070488  AUTISM
# 6  -0.014673  AUTISM
# 7  -0.010311  AUTISM
# 8   -0.01231  AUTISM
# 9   0.072261  AUTISM
# 10 -0.047075  AUTISM
#
# [11 rows x 49 columns]

# %%
filename3 = "./dataset - Copy/autism/Bader_Autism_24_11_2011S001R01.dat"
with b2k.BCI2kReader(filename3) as test3:
        my_states = test3.read(-1)
        my_signals3, stateslice3 = test3[100:5000]
        
plot_autism_eeg = pd.DataFrame(my_signals3)
plot_autism_eeg = pd.DataFrame.transpose(plot_autism_eeg)

plt.figure(figsize = (20,5))
plt.plot(plot_autism_eeg)
plt.legend(['FP1', 'F3', 'F7', 'T3', 'T5', 'O1', 'C4', 'FP2', 'Fz', 'F4', 'F8', 'C3', 'Cz', 'Pz', 'Oz', 'O2',],
            loc='upper right', title='Channels')
plt.title("Autism EEG signal Signature",  fontsize=40, color="green")
# Out:
# Text(0.5, 1.0, 'Autism EEG signal Signature')

# %%
plot_normal_eeg = pd.DataFrame(my_signals)
plot_normal_eeg = pd.DataFrame.transpose(plot_normal_eeg)

plt.figure(figsize = (20,5))
plt.plot(plot_normal_eeg)
plt.legend(['FP1', 'F3', 'F7', 'T3', 'T5', 'O1', 'C4', 'FP2', 'Fz', 'F4', 'F8', 'C3', 'Cz', 'Pz', 'Oz', 'O2',],
            loc='upper right', title='Channels')
plt.title("Normal EEG signal Signature",  fontsize=40, color="green")
# Out:
# Text(0.5, 1.0, 'Normal EEG signal Signature')

# %%
raw2.shape
# Out:
# (16, 4900)

# %%
plot_autism_eeg.index
# Out:
# RangeIndex(start=0, stop=4900, step=1)

# %%
all_fixed_eeg_dataset = pd.DataFrame([],)

all_fixed_eeg_dataset = all_fixed_eeg_dataset.append(df_normal)
all_fixed_eeg_dataset = all_fixed_eeg_dataset.append(df_epileps)

# %%
all_fixed_eeg_dataset.head(100)
# Out:
#            0           1         2          3           4         5   \
# 0   -0.624347   23.979383 -0.026037   0.116477   19.913599  0.005849
# 1   -0.676386   19.131838 -0.035354   0.368772   17.258625  0.021367
# 2   -0.233317   29.305481 -0.007962  -1.072103   29.843842 -0.035924
# 3   -1.274891   29.377941 -0.043396    -0.2455    28.67967  -0.00856
# 4    2.870057   31.392519  0.091425    2.72708   23.715925  0.114989
# 0   -3.104909   34.016403 -0.091277  -8.819782    56.12722 -0.157139
# 1   44.203735  455.095703  0.097131  91.362656  549.767212  0.166184
# 2   -8.550959   91.352348 -0.093604 -14.699034  106.559555 -0.137942
# 3   -1.037109   33.312073 -0.031133  -7.550764   57.545147 -0.131215
# 4    0.591081   310.90451  0.001901   6.541457   91.078812  0.071822
# 1  -0.009455  AUTISM
# 2   -0.06915  AUTISM
# 3  -0.038259  AUTISM
# 4   0.078434  AUTISM
# 5  -0.070488  AUTISM
# 6  -0.014673  AUTISM
# 7  -0.010311  AUTISM
# 8   -0.01231  AUTISM
# 9   0.072261  AUTISM
# 10 -0.047075  AUTISM
#
# [16 rows x 49 columns]

# %%
label_mapping = {'NORMAL': 0, 'AUTISM': 1}

# %%
from sklearn.model_selection import train_test_split
def preprocess_inputs(df):
    df = df.copy()
    
    df[48] = df[48].replace(label_mapping)
    
    y = df[48].copy()
    X = df.drop(48, axis=1).copy()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(all_fixed_eeg_dataset)

# %%
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
X_train
# Out:
#            0           1         2          3           4         5   \
# 4    0.591081  310.904510  0.001901   6.541457   91.078812  0.071822
# 3   -1.037109   33.312073 -0.031133  -7.550764   57.545147 -0.131215
# 6   -0.560912   76.023560 -0.007378  -1.246537   61.854919 -0.020153
# 3   -1.274891   29.377941 -0.043396  -0.245500   28.679670 -0.008560
# 1   -0.676386   19.131838 -0.035354   0.368772   17.258625  0.021367
# 1   44.203735  455.095703  0.097131  91.362656  549.767212  0.166184
# 10  -6.008857  102.754066 -0.058478  -8.091721  143.963516 -0.056207
# 7   -0.768482   34.711796 -0.022139  -2.048633   27.969870 -0.073244
# 2   -0.233317   29.305481 -0.007962  -1.072103   29.843842 -0.035924
# 8   -1.871585   43.747368 -0.042782  -1.327664   22.958767 -0.057828
# 9    1.907379   41.650661  0.045795   1.626422   24.721689  0.065789
#
#           6           7         8         9   ...        38        39  \
# 4   7.374287  129.444763  0.056969  8.847253  ...  0.081489  4.435018
# 3  -1.069819   28.474209 -0.037572  0.186861  ...  0.037243  2.043145
# 6  -1.687734   48.008522 -0.035155 -1.205456  ... -0.015831 -0.800648
# 3  -3.985551   28.727942 -0.138734 -1.126613  ...  0.047145  1.071085
# 1  -0.297263   22.396791 -0.013273 -0.454821  ...  0.015087 -1.362617
# 1   1.134602  343.217102  0.003306  2.881620  ...  0.148525 -3.187153
# 10 -4.327903  105.304161 -0.041099 -7.982169  ... -0.069508 -6.694507
# 7   1.923287   24.240623  0.079341 -1.003429  ... -0.004497  0.059959
# 2   2.780742   31.387653  0.088593  0.057959  ... -0.022178 -0.669388
# 8  -0.627061   19.183924 -0.032687 -0.475463  ... -0.051784 -1.111480
# 9   0.210452   28.381100  0.007415  0.635910  ...  0.073996  2.161743
#
#             40        41         42          43        44        45  \
# 4    52.149452  0.085044   3.727485   52.248840  0.071341  3.944820
# 3    34.347099  0.059485  -0.184046   27.136555 -0.006782 -1.030657
# 6    45.191753 -0.017717  -0.758953   47.726425 -0.015902 -0.769015
# 3    29.261433  0.036604   1.460634   26.562658  0.054988  1.432005
# 1    17.229414 -0.079087  -2.059880   19.018234 -0.108311 -1.570773
# 1   323.585388 -0.009849  -3.991848  293.772247 -0.013588 -3.446635
# 10  101.011597 -0.066275  -7.693645  123.466301 -0.062314 -6.523611
# 7    26.261909  0.002283  -0.826784   53.443165 -0.015470 -0.455056
# 2    27.014055 -0.024779   0.482056   27.717913  0.017391  1.925537
# 8    21.750071 -0.051102  13.829736  163.514069  0.084578 -1.258452
# 9    24.025276  0.089978   1.694341   25.341330  0.066861  1.854930
#
#             46        47
# 4    50.294724  0.078434
# 3    26.939100 -0.038259
# 6    52.411179 -0.014673
# 3    26.860680  0.053312
# 1    17.785280 -0.088319
# 1   364.523651 -0.009455
# 10  138.578613 -0.047075
# 7    44.132179 -0.010311
# 2    28.183655  0.068321
# 8   102.229568 -0.012310
# 9    25.669868  0.072261
#
# [11 rows x 48 columns]

# %%
y_train
# Out:
# 4     1
# 3     1
# 6     1
# 3     0
# 1     0
# 1     1
# 10    1
# 7     1
# 2     0
# 8     1
# 9     1
# Name: 48, dtype: int64

# %%
import tensorflow as tf
# inputs = tf.keras.Input(shape=(X_train.shape[1],))

# expand_dims = tf.expand_dims(inputs, axis=2)

# gru = tf.keras.layers.GRU(256, return_sequences=True)(expand_dims)

# flatten = tf.keras.layers.Flatten()(gru)

# outputs = tf.keras.layers.Dense(1, activation='sigmoid')(flatten)


model =         tf.keras.layers.Dense(512, input_shape=[48]),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1024, activation='relu'),
        
        tf.keras.layers.Dense(512, activation='softmax'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
print(model.summary())
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.resource has been moved to tensorflow.python.trackable.resource. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.graph_view has been moved to tensorflow.python.checkpoint.graph_view. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               25088
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 25,601
# Trainable params: 25,601
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(
    optimizer=RMSprop(lr=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    validation_data = (X_test,y_test),
    batch_size=500,
    epochs=200,
#     callbacks=[
#         tf.keras.callbacks.EarlyStopping(
#             monitor='val_loss',
#             patience=3,
#             restore_best_weights=True
#         )
#    ]
)
# Out:
# Epoch 1/200
# C:\Users\YAP\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:140: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 0s 498ms/step - loss: 0.9547 - accuracy: 0.7273 - val_loss: 9.8865 - val_accuracy: 0.4000
# Epoch 2/200
# 1/1 [==============================] - 0s 45ms/step - loss: 3.3839 - accuracy: 0.4545 - val_loss: 0.8201 - val_accuracy: 0.4000
# Epoch 3/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9161 - accuracy: 0.7273 - val_loss: 0.9239 - val_accuracy: 0.4000
# Epoch 4/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7888 - accuracy: 0.7273 - val_loss: 1.7400 - val_accuracy: 0.6000
# Epoch 5/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6894 - accuracy: 0.7273 - val_loss: 2.6056 - val_accuracy: 0.6000
# Epoch 6/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6277 - accuracy: 0.7273 - val_loss: 3.1490 - val_accuracy: 0.6000
# Epoch 7/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6055 - accuracy: 0.7273 - val_loss: 3.2174 - val_accuracy: 0.6000
# Epoch 8/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5974 - accuracy: 0.7273 - val_loss: 3.2065 - val_accuracy: 0.6000
# Epoch 9/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5897 - accuracy: 0.7273 - val_loss: 3.2204 - val_accuracy: 0.6000
# Epoch 10/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5821 - accuracy: 0.7273 - val_loss: 3.2236 - val_accuracy: 0.6000
# Epoch 11/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5747 - accuracy: 0.7273 - val_loss: 3.2308 - val_accuracy: 0.6000
# Epoch 12/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5673 - accuracy: 0.7273 - val_loss: 3.2349 - val_accuracy: 0.6000
# Epoch 13/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5601 - accuracy: 0.7273 - val_loss: 3.2396 - val_accuracy: 0.6000
# Epoch 14/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5530 - accuracy: 0.7273 - val_loss: 3.2426 - val_accuracy: 0.6000
# Epoch 15/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5459 - accuracy: 0.7273 - val_loss: 3.2451 - val_accuracy: 0.6000
# Epoch 16/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.
200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2449 - accuracy: 0.8182 - val_loss: 2.5964 - val_accuracy: 0.6000
# Epoch 85/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2041 - accuracy: 1.0000 - val_loss: 0.3862 - val_accuracy: 0.8000
# Epoch 86/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2374 - accuracy: 0.8182 - val_loss: 2.5460 - val_accuracy: 0.6000
# Epoch 87/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1977 - accuracy: 1.0000 - val_loss: 0.3817 - val_accuracy: 0.8000
# Epoch 88/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2301 - accuracy: 0.8182 - val_loss: 2.4960 - val_accuracy: 0.6000
# Epoch 89/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1914 - accuracy: 1.0000 - val_loss: 0.3774 - val_accuracy: 0.8000
# Epoch 90/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2230 - accuracy: 0.8182 - val_loss: 2.4463 - val_accuracy: 0.6000
# Epoch 91/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1854 - accuracy: 1.0000 - val_loss: 0.3732 - val_accuracy: 0.8000
# Epoch 92/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2161 - accuracy: 0.8182 - val_loss: 2.3972 - val_accuracy: 0.6000
# Epoch 93/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1796 - accuracy: 1.0000 - val_loss: 0.3691 - val_accuracy: 0.8000
# Epoch 94/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2095 - accuracy: 0.8182 - val_loss: 2.3485 - val_accuracy: 0.6000
# Epoch 95/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1739 - accuracy: 1.0000 - val_loss: 0.3651 - val_accuracy: 0.8000
# Epoch 96/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2030 - accuracy: 0.8182 - val_loss: 2.3004 - val_accuracy: 0.6000
# Epoch 97/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1684 - accuracy: 1.0000 - val_loss: 0.3612 - val_accuracy: 0.8000
# Epoch 98/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1967 - accuracy: 0.8182 - val_loss: 2.2528 - val_accuracy: 0.6000
# Epoch 99/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1631 - accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 0.8000
# Epoch 100/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1906 - accuracy: 0.8182 - val_loss: 2.2057 - val_accuracy: 0.6000
# Epoch 101/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1579 - accuracy: 1.0000 - val_loss: 0.3536 - val_accuracy: 0.8000
# Epoch 102/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1846 - accuracy: 0.8182 - val_loss: 2.1591 - val_accuracy: 0.6000
# Epoch 103/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1529 - accuracy: 1.0000 - val_loss: 0.3499 - val_accuracy: 0.8000
# Epoch 104/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1788 - accuracy: 0.8182 - val_loss: 2.1128 - val_accuracy: 0.6000
# Epoch 105/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1481 - accuracy: 1.0000 - val_loss: 0.3462 - val_accuracy: 0.8000
# Epoch 106/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1732 - accuracy: 0.8182 - val_loss: 2.0668 - val_accuracy: 0.6000
# Epoch 107/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1434 - accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.8000
# Epoch 108/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1678 - accuracy: 0.9091 - val_loss: 2.0210 - val_accuracy: 0.6000
# Epoch 109/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1388 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.8000
# Epoch 110/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1625 - accuracy: 1.0000 - val_loss: 1.9754 - val_accuracy: 0.6000
# Epoch 111/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1344 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.8000
# Epoch 112/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1573 - accuracy: 1.0000 - val_loss: 1.9297 - val_accuracy: 0.6000
# Epoch 113/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1301 - accuracy: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.8000
# Epoch 114/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1523 - accuracy: 1.0000 - val_loss: 1.8841 - val_accuracy: 0.6000
# Epoch 115/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1260 - accuracy: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.8000
# Epoch 116/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1475 - accuracy: 1.0000 - val_loss: 1.8382 - val_accuracy: 0.6000
# Epoch 117/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1220 - accuracy: 1.0000 - val_loss: 0.3252 - val_accuracy: 0.8000
# Epoch 118/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1427 - accuracy: 1.0000 - val_loss: 1.7922 - val_accuracy: 0.6000
# Epoch 119/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1181 - accuracy: 1.0000 - val_loss: 0.3217 - val_accuracy: 0.8000
# Epoch 120/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1382 - accuracy: 1.0000 - val_loss: 1.7459 - val_accuracy: 0.6000
# Epoch 121/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1143 - accuracy: 1.0000 - val_loss: 0.3183 - val_accuracy: 0.8000
# Epoch 122/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1337 - accuracy: 1.0000 - val_loss: 1.6993 - val_accuracy: 0.6000
# Epoch 123/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1107 - accuracy: 1.0000 - val_loss: 0.3149 - val_accuracy: 0.8000
# Epoch 124/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1294 - accuracy: 1.0000 - val_loss: 1.6523 - val_accuracy: 0.6000
# Epoch 125/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1071 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.8000
# Epoch 126/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1252 - accuracy: 1.0000 - val_loss: 1.6049 - val_accuracy: 0.6000
# Epoch 127/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1037 - accuracy: 1.0000 - val_loss: 0.3081 - val_accuracy: 0.8000
# Epoch 128/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1212 - accuracy: 1.0000 - val_loss: 1.5571 - val_accuracy: 0.6000
# Epoch 129/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 0.3048 - val_accuracy: 0.8000
# Epoch 130/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1173 - accuracy: 1.0000 - val_loss: 1.5089 - val_accuracy: 0.6000
# Epoch 131/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0972 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 0.8000
# Epoch 132/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1135 - accuracy: 1.0000 - val_loss: 1.4602 - val_accuracy: 0.6000
# Epoch 133/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0941 - accuracy: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.8000
# Epoch 134/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1098 - accuracy: 1.0000 - val_loss: 1.4110 - val_accuracy: 0.6000
# Epoch 135/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0911 - accuracy: 1.0000 - val_loss: 0.2946 - val_accuracy: 0.8000
# Epoch 136/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1062 - accuracy: 1.0000 - val_loss: 1.3615 - val_accuracy: 0.6000
# Epoch 137/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.8000
# Epoch 138/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1028 - accuracy: 1.0000 - val_loss: 1.3116 - val_accuracy: 0.6000
# Epoch 139/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0854 - accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.8000
# Epoch 140/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0994 - accuracy: 1.0000 - val_loss: 1.2613 - val_accuracy: 0.6000
# Epoch 141/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 0.2845 - val_accuracy: 0.8000
# Epoch 142/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0962 - accuracy: 1.0000 - val_loss: 1.2108 - val_accuracy: 0.6000
# Epoch 143/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0800 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.8000
# Epoch 144/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0930 - accuracy: 1.0000 - val_loss: 1.1602 - val_accuracy: 0.6000
# Epoch 145/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.2778 - val_accuracy: 0.8000
# Epoch 146/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0900 - accuracy: 1.0000 - val_loss: 1.1096 - val_accuracy: 0.6000
# Epoch 147/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 0.2744 - val_accuracy: 0.8000
# Epoch 148/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0871 - accuracy: 1.0000 - val_loss: 1.0590 - val_accuracy: 0.6000
# Epoch 149/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.8000
# Epoch 150/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0842 - accuracy: 1.0000 - val_loss: 1.0089 - val_accuracy: 0.6000
# Epoch 151/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0702 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.8000
# Epoch 152/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 0.9593 - val_accuracy: 0.6000
# Epoch 153/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.8000
# Epoch 154/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0788 - accuracy: 1.0000 - val_loss: 0.9106 - val_accuracy: 0.6000
# Epoch 155/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.8000
# Epoch 156/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0762 - accuracy: 1.0000 - val_loss: 0.8632 - val_accuracy: 0.6000
# Epoch 157/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.8000
# Epoch 158/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0737 - accuracy: 1.0000 - val_loss: 0.8174 - val_accuracy: 0.6000
# Epoch 159/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0615 - accuracy: 1.0000 - val_loss: 0.2546 - val_accuracy: 0.8000
# Epoch 160/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.7736 - val_accuracy: 0.6000
# Epoch 161/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.2513 - val_accuracy: 0.8000
# Epoch 162/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 0.7323 - val_accuracy: 0.6000
# Epoch 163/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.8000
# Epoch 164/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.6938 - val_accuracy: 0.6000
# Epoch 165/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.8000
# Epoch 166/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0644 - accuracy: 1.0000 - val_loss: 0.6585 - val_accuracy: 0.6000
# Epoch 167/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.8000
# Epoch 168/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.6265 - val_accuracy: 0.8000
# Epoch 169/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.8000
# Epoch 170/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0602 - accuracy: 1.0000 - val_loss: 0.5980 - val_accuracy: 0.8000
# Epoch 171/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.8000
# Epoch 172/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.5729 - val_accuracy: 0.8000
# Epoch 173/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.8000
# Epoch 174/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0563 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8000
# Epoch 175/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0472 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.8000
# Epoch 176/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.5321 - val_accuracy: 0.8000
# Epoch 177/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.8000
# Epoch 178/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8000
# Epoch 179/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.8000
# Epoch 180/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.5019 - val_accuracy: 0.8000
# Epoch 181/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.2196 - val_accuracy: 0.8000
# Epoch 182/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.8000
# Epoch 183/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.8000
# Epoch 184/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0476 - accuracy: 1.0000 - val_loss: 0.4793 - val_accuracy: 0.8000
# Epoch 185/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.8000
# Epoch 186/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0460 - accuracy: 1.0000 - val_loss: 0.4701 - val_accuracy: 0.8000
# Epoch 187/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.8000
# Epoch 188/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.4620 - val_accuracy: 0.8000
# Epoch 189/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.8000
# Epoch 190/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.4546 - val_accuracy: 0.8000
# Epoch 191/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.8000
# Epoch 192/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.4479 - val_accuracy: 0.8000
# Epoch 193/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.8000
# Epoch 194/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.4417 - val_accuracy: 0.8000
# Epoch 195/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.8000
# Epoch 196/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.8000
# Epoch 197/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.8000
# Epoch 198/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.4303 - val_accuracy: 0.8000
# Epoch 199/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.8000
# Epoch 200/200
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.8000

# %%
model_acc = model.evaluate(X_test.values.astype(np.float32), y_test, verbose=0)[1]
print("Test Accuracy: {:.3f}%".format(model_acc * 100))
# Out:
# Test Accuracy: 80.000%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = np.array(list(map(lambda x: np.argmax(x), model.predict(X_test.values.astype(np.float32)))))

cm = confusion_matrix(y_test, y_pred)
clr = classification_report(y_test, y_pred, target_names=label_mapping.keys())

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cbar=False, cmap='Blues')
plt.xticks(np.arange(2) + 0.5, label_mapping.keys())
plt.yticks(np.arange(2) + 0.5, label_mapping.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# C:\Users\YAP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\YAP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\YAP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#       NORMAL       0.40      1.00      0.57         2
#       AUTISM       0.00      0.00      0.00         3
#
#     accuracy                           0.40         5
#    macro avg       0.20      0.50      0.29         5
# weighted avg       0.16      0.40      0.23         5

# %%
import matplotlib.pyplot as plt

# Plot the model results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def data_extraction_pred(raw):
    combine_dataframe = []
    for i in range(16):
        mean = raw.values[i].mean() #mean setiap channel (channel = index array)
        combine_dataframe.append(float(mean))

        std = raw.values[i].std()
        combine_dataframe.append(float(std))

        snr = signaltonoise(raw.values[i])
        combine_dataframe.append(float(snr))
    
    final_dataframe = pd.DataFrame(combine_dataframe, index = ['FP1_mean', 'FP1_std', 'FP1_snr', 'F3_mean', 'F3_std', 'F3_snr', 'F7_mean', 'F7_std', 'F7_snr', 'T3_mean', 'T3_std', 'T3_snr','T5_mean', 'T5_std', 'T5_snr','O1_mean', 'O1_std', 'O1_snr','C4_mean', 'C4_std', 'C4_snr','FP2_mean', 'FP2_std', 'FP2_snr','Fz_mean', 'Fz_std', 'Fz_snr','F4_mean', 'F4_std', 'F4_snr','F8_mean', 'F8_std', 'F8_snr','C3_mean', 'C3_std', 'C3_snr','Cz_mean', 'Cz_std', 'Cz_snr','Pz_mean', 'Pz_std', 'Pz_snr','Oz_mean', 'Oz_std', 'Oz_snr','O2_mean', 'O2_std', 'O2_snr'])
    final_dataframe = pd.DataFrame(combine_dataframe)
    final_dataframe = pd.DataFrame.transpose(final_dataframe)
    final_dataframe.reset_index()
    return final_dataframe

# %%
classes = model.predict(data_extraction_pred(plot_normal_eeg), batch_size=500)
print(classes[0])
if classes[0] < 0.5:
    print("its Autism")
else:
    print("its Normal")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [0.34983397]
# its Autism

# %%
classes = model.predict(data_extraction_pred(plot_autism_eeg), batch_size=500)
print(classes[0])
if classes[0] < 0.5:
    print("its Autism")
else:
    print("its Normal")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [8.1407336e-07]
# its Autism

# %%
df_normal = pd.DataFrame([], )
label = 'NORMAL'
for filename in glob.glob('./dataset - Copy/normal/*.dat'):
    with b2k.BCI2kReader(filename) as test:
        my_states = test.read(-1)
        my_signals, stateslice = test[100:5000]
        raw = pd.DataFrame(my_signals)
        raw = pd.DataFrame.transpose(raw)
        classes = model.predict(data_extraction_pred(raw), batch_size=500)
        print(classes[0])
        if classes[0] < 0.5:
            print("its Autism")
        else:
            print("its Normal")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [7.461743e-07]
# its Autism
# 1/1 [==============================] - 0s 16ms/step
# [0.00114199]
# its Autism
# 1/1 [==============================] - 0s 16ms/step
# [1.]
# its Normal
# 1/1 [==============================] - 0s 16ms/step
# [1.]
# its Normal
# 1/1 [==============================] - 0s 19ms/step
# [0.34983397]
# its Autism

# %%
df_normal = pd.DataFrame([], )
label = 'AUTISM'
for filename in glob.glob('./dataset - Copy/autism/*.dat'):
    with b2k.BCI2kReader(filename) as test:
        my_states = test.read(-1)
        my_signals, stateslice = test[100:5000]
        raw = pd.DataFrame(my_signals)
        raw = pd.DataFrame.transpose(raw)
        classes = model.predict(data_extraction_pred(raw), batch_size=500)
        print(classes[0])
        if classes[0] < 0.5:
            print("its Autism")
        else:
            print("its Normal")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [8.1407336e-07]
# its Autism
# 1/1 [==============================] - 0s 22ms/step
# [8.962766e-19]
# its Autism
# 1/1 [==============================] - 0s 16ms/step
# [1.]
# its Normal
# 1/1 [==============================] - 0s 14ms/step
# [9.226862e-10]
# its Autism
# 1/1 [==============================] - 0s 17ms/step
# [1.]
# its Normal
# 1/1 [==============================] - 0s 31ms/step
# [1.]
# its Normal
# 1/1 [==============================] - 0s 16ms/step
# [0.99997497]
# its Normal
# 1/1 [==============================] - 0s 16ms/step
# [0.00020411]
# its Autism
# 1/1 [==============================] - 0s 16ms/step
# [0.99999726]
# its Normal
# 1/1 [==============================] - 0s 16ms/step
# [1.]
# its Normal
# 1/1 [==============================] - 0s 16ms/step
# [4.883571e-37]
# its Autism

# %%
export_dir = 'saved_model'

# Use the tf.saved_model API to save your model in the SavedModel format
tf.saved_model.save(model, export_dir = export_dir)

# %%
# Select mode of optimization
mode = "Speed" 

if mode == 'Storage':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_SIZE
elif mode == 'Speed':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_LATENCY
else:
    optimization = tf.lite.Optimize.DEFAULT

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
converter.target_spec.supported_ops = [
  tf.lite.OpsSet.TFLITE_BUILTINS, # enable TensorFlow Lite ops.
  tf.lite.OpsSet.SELECT_TF_OPS # enable TensorFlow ops.
]
tflite_model = converter.convert()
open("converted_model.tflite", "wb").write(tflite_model)

# %%
model.save('trained_model','/model_save_path')
model.save('trained_model.h5')
print(' Model saved ')
