# %%
import mne
from BCI2kReader import BCI2kReader as b2k
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %%
raw = pd.DataFrame(my_signals)
raw = pd.DataFrame.transpose(raw)

# %%
raw.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
plt.figure(figsize = (20,5))
plt.plot(raw)
# Out:
# [<matplotlib.lines.Line2D at 0x1d24689c2b0>,
#  <matplotlib.lines.Line2D at 0x1d246b7ef40>,
#  <matplotlib.lines.Line2D at 0x1d246d35e20>,
#  <matplotlib.lines.Line2D at 0x1d246d35f40>,
#  <matplotlib.lines.Line2D at 0x1d246d320a0>,
#  <matplotlib.lines.Line2D at 0x1d246d321c0>,
#  <matplotlib.lines.Line2D at 0x1d246d322e0>,
#  <matplotlib.lines.Line2D at 0x1d246d32400>,
#  <matplotlib.lines.Line2D at 0x1d246d32520>,
#  <matplotlib.lines.Line2D at 0x1d246d32640>,
#  <matplotlib.lines.Line2D at 0x1d246d839a0>,
#  <matplotlib.lines.Line2D at 0x1d246d32760>,
#  <matplotlib.lines.Line2D at 0x1d246d32970>,
#  <matplotlib.lines.Line2D at 0x1d246d32a90>,
#  <matplotlib.lines.Line2D at 0x1d246d32bb0>,
#  <matplotlib.lines.Line2D at 0x1d246d32cd0>]

# %%
def signaltonoise(a, axis=0, ddof=0):
    a = np.asanyarray(a)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.where(sd == 0, 0, m/sd)

# %%
def data_extraction_all(raw):
    combine_dataframe = []
    for i in range(16):
        mean = raw.values[i] #mean setiap channel (channel = index array)
        combine_dataframe.append(mean)

        #std = raw.values[i].std()
        #combine_dataframe.append(std)

        #snr = signaltonoise(raw.values[i])
        #combine_dataframe.append(snr)
#        index= ['FP1', 'F3', 'F7', 'T3', 'T5', 'O1', 'C4', 'FP2', 'Fz', 'F4', 'F8', 'C3', 'Cz', 'Pz', 'Oz', 'O2', 'label']
    combine_dataframe.append(1)
    final_dataframe = pd.DataFrame(combine_dataframe)
    final_dataframe = pd.DataFrame.transpose(final_dataframe)
    final_dataframe.reset_index()
    return final_dataframe

# %%
import glob
import os
df_normal = pd.DataFrame([], )
label = 0
for filename in glob.glob('./dataset/normal/*.dat'):
    with b2k.BCI2kReader(filename) as test:
        my_states = test.read(-1)
        my_signals, stateslice = test[100:600]
        raw = pd.DataFrame(my_signals)
        #raw_fix = pd.concat([raw, raw])
        #raw_fix = pd.DataFrame.transpose(raw)
        
        df_normal = df_normal.append(data_extraction_all(raw))
        
        #df.append(data_extraction_all(raw))


#df_normal = pd.dataframe(index= df_normal, ['FP1', 'F3', 'F7', 'T3', 'T5', 'O1', 'C4', 'FP2', 'Fz', 'F4', 'F8', 'C3', 'Cz', 'Pz', 'Oz', 'O2'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19380/1177381989.py in <module>
#      11         #raw_fix = pd.DataFrame.transpose(raw)
#      12
# ---> 13         df_normal = df_normal.append(data_extraction_all(raw))
#      14
#      15         #df.append(data_extraction_all(raw))
#
# ~\AppData\Local\Temp/ipykernel_19380/147871727.py in data_extraction_all(raw)
#      12 #        index= ['FP1', 'F3', 'F7', 'T3', 'T5', 'O1', 'C4', 'FP2', 'Fz', 'F4', 'F8', 'C3', 'Cz', 'Pz', 'Oz', 'O2', 'label']
#      13     combine_dataframe.append(1)
# ---> 14     final_dataframe = pd.DataFrame(combine_dataframe)
#      15     final_dataframe = pd.DataFrame.transpose(final_dataframe)
#      16     final_dataframe.reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                         # ndarray], Index, Series], Sequence[Any]]"
#     693                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 694                     arrays, columns, index = nested_data_to_arrays(
#     695                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     696                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     481         columns = ensure_index(data[0]._fields)
#     482
# --> 483     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     484     columns = ensure_index(columns)
#     485
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, dtype)
#     802     else:
#     803         # last ditch effort
# --> 804         data = [tuple(x) for x in data]
#     805         arr = _list_to_arrays(data)
#     806
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in <listcomp>(.0)
#     802     else:
#     803         # last ditch effort
# --> 804         data = [tuple(x) for x in data]
#     805         arr = _list_to_arrays(data)
#     806
#
# TypeError: 'int' object is not iterable

# %%
#problem : bagaimana cara otomatis untuk menghitung featur statisik (mean, standar deviasi, SNR)
#-- pada setuap channel (channel = index dataframe)
#-- mem-merge semua fitur jadi satu sebanyak 16 fitur (1 channel mempunyai 3 fitur statistik)

# %%
#df_normal.reset_index(drop=True, inplace=True)   
#df_normal = pd.DataFrame.transpose(df_normal)
#df_normal = pd.DataFrame.transpose(df_normal)
df_normal.head(17)
# Out:
#            0          1       2       3          4          5          6   \
# 0   -1.551000  22.539000   5.247   3.729  24.684000  40.194000  20.063999
# 1   -4.356000  20.691000   3.465   2.838  22.044001  35.442001  18.348000
# 2   -6.831000  21.252001   2.706   4.224  19.007999  32.109001  19.041000
# 3   -7.524000  22.638000   4.290   1.914  21.351000  36.035999  21.615000
# 4   -7.623000  23.034000   7.689  -1.452  25.938000  43.064999  23.034000
# 5   -7.194000  22.737000   8.580  -0.891  25.575001  45.473999  21.318001
# 6   -2.376000  23.528999   3.861   3.036  23.858999  45.176998  19.865999
# 7    4.752000  25.806000  -0.165   8.316  27.521999  47.256001  22.605000
# 8    4.323000  27.455999   4.092  13.959  31.812000  48.444000  25.707001
# 9   -5.907000  27.587999  12.276  18.975  31.514999  46.232998  24.914999
# 10 -14.850000  26.961000  14.784  22.143  31.812000  45.672001  23.858999
# 11 -15.048000  23.990999  10.593  21.351  34.914001  47.223000  25.146000
# 12 -12.507000  17.127001   4.719  16.104  34.452000  44.945999  25.146000
# 13 -13.794000  10.824000   1.056   9.834  28.545000  39.071999  22.934999
# 14 -17.292000  10.197000   1.023   5.148  23.264999  34.848000  21.450001
# 15 -18.447001  13.233000   2.772   2.310  22.077000  32.933998  21.549000
# 16 -16.698000  14.982000   4.422   1.881  21.879000  30.459000  22.770000
#
#         7          8       9   ...      6          7          8          9   \
# 0    3.399  15.312000  12.177  ...  -3.102 -18.941999 -23.826000 -25.971001
# 1   12.738  11.880000   9.141  ...  -1.287 -22.176001 -23.792999 -26.927999
# 2   27.027  10.164000   5.280  ...  -1.287 -28.313999 -25.806000 -27.851999
# 3   27.489  13.794000   5.841  ...  -3.993 -31.712999 -28.215000 -29.898001
# 4   12.837  18.414000   9.174  ...  -5.643 -32.505001 -27.951000 -30.294001
# 5   -0.561  17.919001   8.745  ...  -6.072 -37.058998 -27.785999 -29.832001
# 6    1.188  15.015000   4.224  ...  -9.207 -42.239998 -30.723000 -32.570999
# 7   11.319  15.444000   0.528  ... -13.530 -38.511002 -32.702999 -35.738998
# 8   11.583  17.721001  -0.396  ... -12.375 -28.907999 -29.469000 -32.702999
# 9   -0.660  17.523001   0.858  ...  -5.049 -23.924999 -24.254999 -25.377001
# 10 -10.296  15.972000   4.125  ...   0.693 -24.948000 -21.780001 -21.780001
# 11  -6.171  14.850000   6.831  ...  -0.495 -25.080000 -21.483000 -23.760000
# 12   3.564  11.715000   6.006  ...  -3.531 -16.500000 -18.249001 -24.584999
# 13   3.828   6.204000   2.607  ...  -1.881  -2.145000  -9.966000 -19.305000
# 14  -1.980   2.277000  -0.693  ...   1.254   3.465000  -2.904000 -12.210000
# 15  -0.132   2.640000  -1.881  ...   0.726  -2.310000  -3.597000  -9.537000
# 16   5.379   5.775000  -1.023  ...  -2.277  -7.260000 -10.296000 -12.276000
#
#            10         11         12         13         14         15
# 0  -26.631001 -10.164000  13.563000  14.091000  30.723000  27.521999
# 1  -17.952000  -9.603000  19.139999  20.063999  35.706001  34.946999
# 2  -14.388000  -9.867000  18.809999  23.430000  39.039001  39.402000
# 3  -20.129999 -10.493999  17.292000  23.462999  39.731998  39.764999
# 4  -29.007000  -8.580000  19.865999  23.396999  39.500999  39.764999
# 5  -35.738998  -5.544000  15.180000  23.628000  39.071999  41.118000
# 6  -38.279999  -5.148000   7.491000  21.516001  36.167999  40.326000
# 7  -35.574001  -6.831000  11.979000  17.787001  30.954000  35.541000
# 8  -27.719999  -6.666000  19.601999  16.500000  27.191999  30.624001
# 9  -18.975000  -2.706000  18.084000  19.007999  26.202000  27.753000
# 10 -17.292000   3.234000  17.490000  22.473000  26.103001  24.948000
# 11 -23.298000   8.316000  21.813000  23.298000  25.476000  20.723999
# 12 -25.244999  12.078000  22.341000  21.615000  24.882000  16.896000
# 13 -16.764000  15.180000  22.605000  19.733999  25.178999  15.675000
# 14  -7.293000  15.708000  25.674000  16.962000  24.288000  15.048000
# 15  -7.260000  12.837000  21.945000  12.078000  20.459999  12.111000
# 16 -17.292000   9.108000  15.213000   7.590000  16.500000   8.217000
#
# [17 rows x 144 columns]

# %%
import seaborn as sns
sns.lmplot('1', '2', 
           data=df_normal,
           fit_reg=False,
           hue="1",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('FP1_mean vs FP1_std')


plt.show()
# Out:
# C:\Users\YAP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19380/1642112175.py in <module>
#       1 import seaborn as sns
# ----> 2 sns.lmplot('1', '2',
#       3            data=df_normal,
#       4            fit_reg=False,
#       5            hue="1",
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     603     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     604     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 605     data = data[cols]
#     606
#     607     # Initialize the grid
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['1', '2'], dtype='object')] are in the [columns]"

# %%
datafixed.values[1]
# Out:
# array([20.360942840576172, 19.394977569580078, 18.040708541870117,
#        18.01752471923828, 20.265905380249023, 22.782487869262695,
#        22.977439880371094, 23.1267147064209, 24.653932571411133,
#        24.893516540527344, 24.53962516784668, 25.897579193115234,
#        27.733129501342773, 28.26580810546875, 27.854801177978516,
#        28.56406593322754, 1.0], dtype=object)

# %%
def data_extraction_all(raw):
    combine_dataframe = []
    labels = 1
    for i in range(16):
        mean = raw.values[i].mean() #mean setiap channel (channel = index array)
        combine_dataframe.append(mean)

        std = raw.values[i].std()
        combine_dataframe.append(std)

        snr = signaltonoise(raw.values[i])
        combine_dataframe.append(snr)
    combine_dataframe.append(labels)
    final_dataframe = pd.DataFrame(combine_dataframe, index = ['FP1_mean', 'FP1_std', 'FP1_snr', 'F3_mean', 'F3_std', 'F3_snr', 'F7_mean', 'F7_std', 'F7_snr', 'T3_mean', 'T3_std', 'T3_snr','T5_mean', 'T5_std', 'T5_snr','O1_mean', 'O1_std', 'O1_snr','C4_mean', 'C4_std', 'C4_snr','FP2_mean', 'FP2_std', 'FP2_snr','Fz_mean', 'Fz_std', 'Fz_snr','F4_mean', 'F4_std', 'F4_snr','F8_mean', 'F8_std', 'F8_snr','C3_mean', 'C3_std', 'C3_snr','Cz_mean', 'Cz_std', 'Cz_snr','Pz_mean', 'Pz_std', 'Pz_snr','Oz_mean', 'Oz_std', 'Oz_snr','O2_mean', 'O2_std', 'O2_snr','label'])
    final_dataframe = pd.DataFrame.transpose(final_dataframe)
    return final_dataframe

# %%
datafixed2 = data_extraction_all(raw)

# %%
datafixed2.head(49)
# Out:
#     FP1_mean    FP1_std             FP1_snr    F3_mean     F3_std  \
# 0 -95.169937  20.360943  -4.674141883850098 -90.083817  19.394978
#
#                F3_snr    F7_mean     F7_std              F7_snr    T3_mean  \
# 0  -4.644698143005371 -83.657059  18.040709  -4.637126922607422 -79.761002
#
#    ...    Pz_mean     Pz_std              Pz_snr    Oz_mean     Oz_std  \
# 0  ... -75.627747  28.265808  -2.675591230392456 -76.184631  27.854801
#
#                Oz_snr   O2_mean     O2_std               O2_snr label
# 0  -2.735062837600708 -78.88031  28.564066  -2.7615225315093994     1
#
# [1 rows x 49 columns]

# %%
datafixed2 = pd.DataFrame.transpose(datafixed2)

# %%
datafixed2.head()
# Out:
#                            0
# FP1_mean          -95.169937
# FP1_std            20.360943
# FP1_snr   -4.674141883850098
# F3_mean           -90.083817
# F3_std             19.394978

# %%
# f = abs(np.fft.fft(raw.values))
# num = np.size(raw)
# freq = [i/num for i in raw.index]

# spectrum=f.real*f.real+f.imag*f.imag
# nspectrum = spectrum/spectrum[0]
# plt.figure(figsize = (20,5))
# plt.plot(freq,nspectrum)

# %%
# combine_fourier_data = list(zip(nspectrum, freq))
# fourier_dataframe = pd.DataFrame(combine_fourier_data, columns = ['nSpectrum', 'Frequencies'])
# #fourier_dataframe = pd.DataFrame.transpose(fourier_dataframe)
# #fourier_dataframe = pd.DataFrame(combine_fourier_data)

# %%
# fourier_dataframe.head(16)

# %%
filename2 = "./dataset/autism/Mada_Autism_26_5_2011S001R01.dat"
with b2k.BCI2kReader(filename2) as test2:
        my_states = test2.read(-1)
        my_signals2, stateslice2 = test2[100:500]
        #my_signals= test.signals

# %%
raw2 = pd.DataFrame(my_signals2)
raw2 = pd.DataFrame.transpose(raw2)

# %%
plt.figure(figsize = (20,5))
plt.plot(raw2)
# Out:
# [<matplotlib.lines.Line2D at 0x1d249495700>,
#  <matplotlib.lines.Line2D at 0x1d249495730>,
#  <matplotlib.lines.Line2D at 0x1d249495850>,
#  <matplotlib.lines.Line2D at 0x1d249495970>,
#  <matplotlib.lines.Line2D at 0x1d249495a90>,
#  <matplotlib.lines.Line2D at 0x1d249495bb0>,
#  <matplotlib.lines.Line2D at 0x1d249495cd0>,
#  <matplotlib.lines.Line2D at 0x1d249495df0>,
#  <matplotlib.lines.Line2D at 0x1d249495f10>,
#  <matplotlib.lines.Line2D at 0x1d24949e070>,
#  <matplotlib.lines.Line2D at 0x1d2493d1070>,
#  <matplotlib.lines.Line2D at 0x1d24949e190>,
#  <matplotlib.lines.Line2D at 0x1d24949e3a0>,
#  <matplotlib.lines.Line2D at 0x1d24949e4c0>,
#  <matplotlib.lines.Line2D at 0x1d24949e5e0>,
#  <matplotlib.lines.Line2D at 0x1d24949e700>]

# %%
raw2.shape
# Out:
# (400, 16)
