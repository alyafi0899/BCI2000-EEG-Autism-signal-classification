# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib as plt
import keras
from keras.layers import Dense,Conv2D,MaxPool2D,Dropout,Flatten
from keras.models import Sequential
from keras.preprocessing import image
import os
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping # Early Stopping
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.utils import img_to_array
import easygui
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.resource has been moved to tensorflow.python.trackable.resource. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.graph_view has been moved to tensorflow.python.checkpoint.graph_view. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.

# %%
base_dir = "./dataset"

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'test')

# Directory with our training pictures
train_normal_dir = os.path.join(train_dir, 'normal')
train_autism_dir = os.path.join(train_dir, 'autism')

# Directory with our validation pictures
validation_normal_dir = os.path.join(validation_dir, 'normal')
validation_autism_dir = os.path.join(validation_dir, 'autism')

# %%
train_normal_fnames = os.listdir( train_normal_dir )
train_autism_fnames = os.listdir( train_autism_dir )

print(train_normal_fnames[:10])
print(train_autism_fnames[:10])
# Out:
# ['.ipynb_checkpoints', 'Amer_Normal_5_5_2011S001R01.dat', 'Amer_Normal_5_5_2011S001R02.dat', 'Amer_Normal_5_5_2011S001R03.dat', 'Dhelal_Normal_15_6_2011S001R01.dat', 'Dhelal_Normal_15_6_2011S001R02.dat', 'Mahmud_Normal_5_5_2011S001R01.dat', 'Mahmud_Normal_5_5_2011S001R02.dat', 'Majdolin_Normal_18_5_2011S001R01.dat', 'Omran_Normal_5_5_2011S001R01.dat']
# ['.ipynb_checkpoints', 'Bader_Autism_24_11_2011S001R01.dat', 'Bader_Autism_24_11_2011S001R05.dat', 'Bader_Autism_24_11_2011S001R07.dat', 'Bader_Autism_24_11_2011S001R08.dat', 'Bader_Autism_24_11_2011S001R09.dat', 'Bader_Autism_24_11_2011S001R10.dat', 'Deena_Autism_23_4_2011S001R01.dat', 'Duaa_Autism_23_4_2011S001R01.dat', 'Mada_Autism_26_5_2011S001R01.dat']

# %%
print('total training Normal images :', len(os.listdir( train_normal_dir ) ))
print('total training Covid images :', len(os.listdir( train_covid_dir ) ))

print('total validation Normal images :', len(os.listdir( validation_normal_dir ) ))
print('total validation Covid images :', len(os.listdir( validation_covid_dir ) ))
# Out:
# total training Normal images : 551
# total training Covid images : 125
# total validation Normal images : 290
# total validation Covid images : 118

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

pic_index = 0 # Index for iterating over images

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_normal_pix = [os.path.join(train_normal_dir, fname) 
                for fname in train_normal_fnames[ pic_index-8:pic_index] 
               ]

next_covid_pix = [os.path.join(train_covid_dir, fname) 
                for fname in train_covid_fnames[ pic_index-8:pic_index]
               ]

for i, img_path in enumerate(next_normal_pix+next_covid_pix):
    # Set up subplot; subplot indices start at 1
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off') # Don't show axes (or gridlines)
    
    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(500,500,3)),

    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(500,500,3)),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(rate=0.25),
    
    tf.keras.layers.Conv2D(32, (3,3),activation='relu',input_shape=(500,500,3)),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(rate=0.25),
    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(500,500,3)),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(rate=0.25),
    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(500,500,3)),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(rate=0.25),
    
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(rate=0.50),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 498, 498, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 496, 496, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 248, 248, 32)     0
#  )
#
#  dropout (Dropout)           (None, 248, 248, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 246, 246, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 32)     0
#  2D)
#
#  dropout_1 (Dropout)         (None, 123, 123, 32)      0
#
#  conv2d_3 (Conv2D)           (None, 121, 121, 32)      9248
#
#  max_pooling2d_2 (MaxPooling  (None, 60, 60, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 60, 60, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 58, 58, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 29, 29, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 29, 29, 32)        0
#
#  flatten (Flatten)           (None, 26912)             0
#
#  dense (Dense)               (None, 64)                1722432
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,760,385
# Trainable params: 1,760,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics = ['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Apply data augmentation
train_datagen = ImageDataGenerator(
      rescale=1./255,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,)

validation_datagen = ImageDataGenerator(rescale=1./255,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size=(500, 500),  # All images will be resized to 150x150
        batch_size=64,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow training images in batches of 128 using train_datagen generator
validation_generator = validation_datagen.flow_from_directory(
        validation_dir,  # This is the source directory for training images
        target_size=(500, 500),  # All images will be resized to 150x150
        batch_size=64,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 676 images belonging to 2 classes.
# Found 408 images belonging to 2 classes.

# %%
# Constant for epochs
EPOCHS = 50
early_stop = EarlyStopping(monitor='val_loss', patience=3)
# Train the model
history = model.fit(
      train_generator,
      epochs=EPOCHS,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=2)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 295s 26s/step - loss: 1.0588 - accuracy: 0.7470 - val_loss: 0.6115 - val_accuracy: 0.7031
# Epoch 2/50
# 11/11 [==============================] - 272s 25s/step - loss: 0.4916 - accuracy: 0.8151 - val_loss: 0.6595 - val_accuracy: 0.6172
# Epoch 3/50
# 11/11 [==============================] - 264s 25s/step - loss: 0.5295 - accuracy: 0.8151 - val_loss: 0.6383 - val_accuracy: 0.7031
# Epoch 4/50
# 11/11 [==============================] - 266s 24s/step - loss: 0.4810 - accuracy: 0.8151 - val_loss: 0.6455 - val_accuracy: 0.7109
# Epoch 5/50
# 11/11 [==============================] - 272s 26s/step - loss: 0.4454 - accuracy: 0.8151 - val_loss: 0.6184 - val_accuracy: 0.7031
# Epoch 6/50
# 11/11 [==============================] - 273s 25s/step - loss: 0.3861 - accuracy: 0.8240 - val_loss: 0.6376 - val_accuracy: 0.7188
# Epoch 7/50
# 11/11 [==============================] - 269s 24s/step - loss: 0.3732 - accuracy: 0.8432 - val_loss: 0.5172 - val_accuracy: 0.7578
# Epoch 8/50
# 11/11 [==============================] - 270s 25s/step - loss: 0.3251 - accuracy: 0.8595 - val_loss: 0.5368 - val_accuracy: 0.7031
# Epoch 9/50
# 11/11 [==============================] - 268s 25s/step - loss: 0.3180 - accuracy: 0.8550 - val_loss: 0.4949 - val_accuracy: 0.7734
# Epoch 10/50
# 11/11 [==============================] - 270s 26s/step - loss: 0.3000 - accuracy: 0.8521 - val_loss: 0.6070 - val_accuracy: 0.7656
# Epoch 11/50
# 11/11 [==============================] - 271s 24s/step - loss: 0.3197 - accuracy: 0.8728 - val_loss: 0.5807 - val_accuracy: 0.8125
# Epoch 12/50
# 11/11 [==============================] - 270s 25s/step - loss: 0.2801 - accuracy: 0.8728 - val_loss: 0.4831 - val_accuracy: 0.8438
# Epoch 13/50
# 11/11 [==============================] - 270s 24s/step - loss: 0.2990 - accuracy: 0.8595 - val_loss: 0.5331 - val_accuracy: 0.8047
# Epoch 14/50
# 11/11 [==============================] - 268s 25s/step - loss: 0.2676 - accuracy: 0.8787 - val_loss: 0.6906 - val_accuracy: 0.7422
# Epoch 15/50
# 11/11 [==============================] - 272s 25s/step - loss: 0.2794 - accuracy: 0.8713 - val_loss: 0.5601 - val_accuracy: 0.7891
# Epoch 16/50
# 11/11 [==============================] - 268s 24s/step - loss: 0.2538 - accuracy: 0.8728 - val_loss: 0.5330 - val_accuracy: 0.7812
# Epoch 17/50
# 11/11 [==============================] - 327s 31s/step - loss: 0.2692 - accuracy: 0.8802 - val_loss: 0.6174 - val_accuracy: 0.8281
# Epoch 18/50
# 11/11 [==============================] - 288s 26s/step - loss: 0.2539 - accuracy: 0.8861 - val_loss: 0.4856 - val_accuracy: 0.8594
# Epoch 19/50
# 11/11 [==============================] - 285s 26s/step - loss: 0.2544 - accuracy: 0.8891 - val_loss: 0.5185 - val_accuracy: 0.8281
# Epoch 20/50
# 11/11 [==============================] - 298s 27s/step - loss: 0.2370 - accuracy: 0.8905 - val_loss: 0.4655 - val_accuracy: 0.8516
# Epoch 21/50
# 11/11 [==============================] - 300s 27s/step - loss: 0.2410 - accuracy: 0.8905 - val_loss: 0.6870 - val_accuracy: 0.8359
# Epoch 22/50
# 11/11 [==============================] - 277s 25s/step - loss: 0.2284 - accuracy: 0.9098 - val_loss: 0.7058 - val_accuracy: 0.8125
# Epoch 23/50
# 11/11 [==============================] - 274s 25s/step - loss: 0.2723 - accuracy: 0.8964 - val_loss: 0.4798 - val_accuracy: 0.7969
# Epoch 24/50
# 11/11 [==============================] - 271s 24s/step - loss: 0.2557 - accuracy: 0.9038 - val_loss: 0.6310 - val_accuracy: 0.8125
# Epoch 25/50
# 11/11 [==============================] - 268s 24s/step - loss: 0.1989 - accuracy: 0.9127 - val_loss: 0.4396 - val_accuracy: 0.8516
# Epoch 26/50
# 11/11 [==============================] - 265s 24s/step - loss: 0.2558 - accuracy: 0.9068 - val_loss: 0.6943 - val_accuracy: 0.7734
# Epoch 27/50
# 11/11 [==============================] - 266s 24s/step - loss: 0.2299 - accuracy: 0.9172 - val_loss: 0.4850 - val_accuracy: 0.8125
# Epoch 28/50
# 11/11 [==============================] - 267s 24s/step - loss: 0.2261 - accuracy: 0.9186 - val_loss: 0.5864 - val_accuracy: 0.8359
# Epoch 29/50
# 11/11 [==============================] - 267s 24s/step - loss: 0.2203 - accuracy: 0.9068 - val_loss: 0.6594 - val_accuracy: 0.8516
# Epoch 30/50
# 11/11 [==============================] - 265s 24s/step - loss: 0.2374 - accuracy: 0.9009 - val_loss: 0.4720 - val_accuracy: 0.8359
# Epoch 31/50
# 11/11 [==============================] - 264s 25s/step - loss: 0.1962 - accuracy: 0.9186 - val_loss: 0.4564 - val_accuracy: 0.8750
# Epoch 32/50
# 11/11 [==============================] - 267s 24s/step - loss: 0.1891 - accuracy: 0.9186 - val_loss: 0.4939 - val_accuracy: 0.8672
# Epoch 33/50
# 11/11 [==============================] - 270s 24s/step - loss: 0.1973 - accuracy: 0.9186 - val_loss: 0.7331 - val_accuracy: 0.8438
# Epoch 34/50
# 11/11 [==============================] - 271s 24s/step - loss: 0.1832 - accuracy: 0.9320 - val_loss: 0.5300 - val_accuracy: 0.8672
# Epoch 35/50
# 11/11 [==============================] - 268s 24s/step - loss: 0.1821 - accuracy: 0.9216 - val_loss: 0.5131 - val_accuracy: 0.8516
# Epoch 36/50
# 11/11 [==============================] - 269s 24s/step - loss: 0.1875 - accuracy: 0.9290 - val_loss: 0.6715 - val_accuracy: 0.8125
# Epoch 37/50
# 11/11 [==============================] - 267s 25s/step - loss: 0.1766 - accuracy: 0.9320 - val_loss: 0.6403 - val_accuracy: 0.8672
# Epoch 38/50
# 11/11 [==============================] - 271s 24s/step - loss: 0.1605 - accuracy: 0.9393 - val_loss: 0.5275 - val_accuracy: 0.8906
# Epoch 39/50
# 11/11 [==============================] - 272s 24s/step - loss: 0.1795 - accuracy: 0.9290 - val_loss: 0.5094 - val_accuracy: 0.8281
# Epoch 40/50
# 11/11 [==============================] - 274s 25s/step - loss: 0.1684 - accuracy: 0.9438 - val_loss: 0.6007 - val_accuracy: 0.8438
# Epoch 41/50
# 11/11 [==============================] - 273s 25s/step - loss: 0.1507 - accuracy: 0.9379 - val_loss: 0.3990 - val_accuracy: 0.9062
# Epoch 42/50
# 11/11 [==============================] - 269s 24s/step - loss: 0.1726 - accuracy: 0.9305 - val_loss: 0.6844 - val_accuracy: 0.8672
# Epoch 43/50
# 11/11 [==============================] - 269s 25s/step - loss: 0.2053 - accuracy: 0.9112 - val_loss: 0.4337 - val_accuracy: 0.8516
# Epoch 44/50
# 11/11 [==============================] - 271s 24s/step - loss: 0.1972 - accuracy: 0.9231 - val_loss: 0.6419 - val_accuracy: 0.8750
# Epoch 45/50
# 11/11 [==============================] - 270s 24s/step - loss: 0.1889 - accuracy: 0.9231 - val_loss: 0.4509 - val_accuracy: 0.8828
# Epoch 46/50
# 11/11 [==============================] - 274s 25s/step - loss: 0.1618 - accuracy: 0.9275 - val_loss: 0.5770 - val_accuracy: 0.8594
# Epoch 47/50
# 11/11 [==============================] - 273s 25s/step - loss: 0.1614 - accuracy: 0.9334 - val_loss: 0.5192 - val_accuracy: 0.8359
# Epoch 48/50
# 11/11 [==============================] - 269s 24s/step - loss: 0.1663 - accuracy: 0.9379 - val_loss: 0.7364 - val_accuracy: 0.8594
# Epoch 49/50
# 11/11 [==============================] - 272s 24s/step - loss: 0.1639 - accuracy: 0.9334 - val_loss: 0.5090 - val_accuracy: 0.9141
# Epoch 50/50
# 11/11 [==============================] - 270s 24s/step - loss: 0.1684 - accuracy: 0.9349 - val_loss: 0.5752 - val_accuracy: 0.8438

# %%
pd.DataFrame(model.history.history).plot()
# Out:
# <AxesSubplot:>

# %%
test_accu = model.evaluate(train_generator)
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# 11/11 [==============================] - 69s 6s/step - loss: 0.1904 - accuracy: 0.9246
# The testing accuracy is : 92.45561957359314 %

# %%
# Plot the model results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
export_dir = 'saved_model'

# Use the tf.saved_model API to save your model in the SavedModel format
tf.saved_model.save(model, export_dir = export_dir)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.trackable_utils has been moved to tensorflow.python.trackable.trackable_utils. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.trackable_utils has been moved to tensorflow.python.trackable.trackable_utils. The old module will be deleted in version 2.11.
# INFO:tensorflow:Assets written to: saved_model\assets
# INFO:tensorflow:Assets written to: saved_model\assets

# %%
# Select mode of optimization
mode = "Speed" 

if mode == 'Storage':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_SIZE
elif mode == 'Speed':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_LATENCY
else:
    optimization = tf.lite.Optimize.DEFAULT

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
converter.target_spec.supported_ops = [
  tf.lite.OpsSet.TFLITE_BUILTINS, # enable TensorFlow Lite ops.
  tf.lite.OpsSet.SELECT_TF_OPS # enable TensorFlow ops.
]
tflite_model = converter.convert()
open("converted_model.tflite", "wb").write(tflite_model)
# Out:
# 7046756

# %%
model.save('trained_model','/model_save_path')
model.save('trained_model.h5')
print(' Model saved ')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: sales forcasting\assets
# INFO:tensorflow:Assets written to: sales forcasting\assets
#  Model saved

# %%
from tensorflow.keras.utils import img_to_array
file = './cov.png'

img = tf.keras.utils.load_img(file, target_size=(500,500))

plt.figure(figsize = (20,20))
plt.imshow(img)
x = img_to_array(img)
x /= 255
img_test = np.expand_dims(x, axis=0)

classes = model.predict(img_test, batch_size=10)
print(classes[0])
if classes[0]<0.5:
    print("its Normal")
else:
    print("its Covid")
# Out:
# 1/1 [==============================] - 0s 73ms/step
# [0.5817736]
# its Covid
