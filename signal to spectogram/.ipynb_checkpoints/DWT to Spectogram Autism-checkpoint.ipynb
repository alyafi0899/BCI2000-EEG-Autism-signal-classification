# %%
import pywt
from BCI2kReader import BCI2kReader as b2k
import scipy as sp
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Bader_Autism_24_11_2011S001R01.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Bader_Autism_24_11_2011S001R05.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Bader_Autism_24_11_2011S001R07.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Bader_Autism_24_11_2011S001R08.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Mada_Autism_26_5_2011S001R01.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Mada_Autism_26_5_2011S001R02.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Mohammed_Autism_9_11_2011S001R01.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Nour_Autism_2_10_2011S001R01.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Nour_Autism_2_10_2011S001R02.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Saud_Autism_1_5_2011S001R01.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')

# %%
import pywt
import scipy as sp
from scipy import signal

#baca data sinyal eeg
filename = "./dataset - Copy/autism/Shahad_Autism_5_6_2011S001R01.dat"
with b2k.BCI2kReader(filename) as test:
        my_signals, stateslice = test[0:1000]
        
coeffs = pywt.dwt2(my_signals, 'haar')
cA, (cH, cV, cD) = coeffs

my_data2 = cA.astype(np.uint8)

plt.figure(figsize=(100,10))    
plt.pcolormesh(my_data2, cmap='jet')
plt.yscale('linear')
plt.axis('off')
plt.savefig('normal_dwt2.png', transparent = True, bbox_inches='tight')
